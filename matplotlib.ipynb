# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x= np.array([1,2,3])

# %%
x
# Out:
# array([1, 2, 3])

# %%
# plot 
# scatter 
# hist 
# bar 
# boxplot 
# pie

# %%
plt.plot (x)
plt.show ()

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.plot(x,y)
plt.show()

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.plot(x,y,marker = '*', markersize= 20)
plt.show()

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.plot(x,y,marker = '*', markersize= 20)
plt.show()

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.title("lineplot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x)
plt.plot(y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 3
#       1 x= np.array([1,2,3,4,5,6,7])
#       2 y =np.array([2,5,3,4,6,7,2])
# ----> 3 plt.title("lineplot")
#       4 plt.xlabel("x axis")
#       5 plt.ylabel("y axis")
#
# TypeError: 'str' object is not callable

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.title("lineplot", fontsize= '20' , fontweight = 'bold' , color= 'pink')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x= np.array([1,2,3,4,5,6,7])
y =np.array([2,5,3,4,6,7,2])
plt.title("lineplot", fontsize= '20' , fontweight = 'bold' , color= 'pink')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid()
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y =np.array([2,5,3,4,6])
plt.scatter(x,y,)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y =np.array([2,5,3,4,6])
c = np.array(['red', 'green', 'blue' , 'yellow', 'pink'])

plt.scatter(x,y, c=c)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y =np.array([2,5,3,4,6])
c = np.array(['red', 'green', 'blue' , 'yellow', 'pink']) #c=color
s = np.array([50,60,20,40,10]) #s=size

plt.scatter(x,y, c=c,s=s)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha=0.5, s = sizes, c = c,cmap='virdis' ) # camap = color map, viridis, nipy_spectral, coolwarm
plt.colorbar()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7352\4239908583.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,alpha=0.5, s = sizes, c = c,cmap='virdis' ) # camap = color map, viridis, nipy_spectral, coolwarm

# %% [markdown]
# ### Barplot ###

# %%
x_point = np.array([1,2,3,4,5])
y_point = np.array([2,4,6,8,10])
#import matplotlib.pyplot as plt
plt.bar(x_point,y_point)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])
plt.barh(x , y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.array([1,2,3,4,5])
y= np.array([2,4,6,8,10])
plt.bar(x ,y , color = "green")
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.array(["A","B","C","D","E",])
y = np.array([1,2,3,4,5])
plt.bar(x, y , color ="pink" , width=0.5)
plt.show()

# %%
x = np.array(["A","B","C","D","E",])
y = np.array([1,2,3,4,5])
c= np.array(["red", "pink","green","yellow","magenta"])
plt.bar(x, y , c=c , width=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[157], line 4
#       2 y = np.array([1,2,3,4,5])
#       3 c= np.array(["red", "pink","green","yellow","magenta"])
# ----> 4 plt.bar(x, y , c=c , width=0.5)
#       5 plt.show()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2990, in bar(x, height, width, bottom, align, data, **kwargs)
#    2979 @_copy_docstring_and_deprecators(Axes.bar)
#    2980 def bar(
#    2981     x: float | ArrayLike,
#    (...)   2988     **kwargs,
#    2989 ) -> BarContainer:
# -> 2990     return gca().bar(
#    2991         x,
#    2992         height,
#    2993         width=width,
#    2994         bottom=bottom,
#    2995         align=align,
#    2996         **({"data": data} if data is not None else {}),
#    2997         **kwargs,
#    2998     )
#
# ...

# %% [markdown]
# ## HISTPLOT ##

# %%
x =np.random.normal(170,10,250)

# %%
plt.hist(x)
# Out:
# (array([ 5.,  6., 16., 25., 47., 53., 42., 30., 20.,  6.]),
#  array([142.96208973, 147.73035256, 152.4986154 , 157.26687823,
#         162.03514107, 166.8034039 , 171.57166674, 176.33992957,
#         181.10819241, 185.87645524, 190.64471808]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## PIECHART ##

# %%
x =np.array([1,2,3,4])
plt.pie(x)
plt.show()

# %%
x =np.array([1,2,3,4])
label = np.array(["O2","CO2","N","other"])
plt.pie(x , labels=label , startangle=90)
plt.show()

# %%
x =np.array([1,2,3,4])
label = np.array(["O2","CO2","N","other"])
myexplode = [0.2,0,0,0]
plt.pie(x , labels=label , startangle=90, explode=myexplode)
plt.show()

# %%
x =np.array([1,2,3,4])
label = np.array(["O2","CO2","N","other"])
myexplode = [0.2,0,0,0]
color = ["red", "skyblue" , "purple" , "magenta"]
plt.pie(x , labels=label , startangle=90, explode=myexplode , shadow= True , colors=color )
plt.show()

# %%
gases = ["Nitrogen" , "Oxygen", "Argon" , "Carbon Diaoxide", "others"]
percentage = [78.09 ,20.95 , 0.93 , 0.04 , 0.01]
colors = ['skyblue' , 'purple' , 'lightgreen' , 'gray' , 'gold' , 'lightcoral']
explode = [0,0.1 , 0 , 0 , 0]

plt.figure(figsize=(8, 8))
plt.pie(percentage , labels=gases , autopct = '%1.2f%%', explode=explode  , colors=color , startangle=250)
plt.show()
